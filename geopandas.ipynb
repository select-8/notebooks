# %%
import geopandas as gpd
import matplotlib
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %%
gdf = gpd.read_file('../work/compass/bikeLife/Data_for_BikeLife/DCC_Bike_Parking_Updated_18112016_ITM.shp')

# %%
# print(gdf)
# gdf.crs

# %%
# %matplotlib inline
# gdf.plot(column='type_stand', cmap=None)

# %%
gdf2 = gpd.read_file('../../Downloads/IRL_adm/IRL_adm1.shp')

# %%
gdf = gdf.to_crs("EPSG:3857")
gdf2 = gdf2.to_crs("EPSG:3857")
# gdf2.crs

# %%
f, ax = plt.subplots(1, figsize=(12, 12))
ax.set_axis_off()
gdf.plot(ax=ax, column='type_stand', cmap=None)
gdf2.plot(ax=ax, column='NAME_1', cmap=None)
plt.show()
